# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 100

# %%
with open ("headers_2018.txt", "r") as file:
    columns = file.readline().split(",")

columns = [col.strip() for col in columns]

# %%
df = pd.read_csv("test_2018.csv", header=None)
df.columns= columns
df
# Out:
#          fl_date op_carrier  op_carrier_fl_num origin dest  crs_dep_time  \
# 0     2018-01-01         UA                508    EWR  IAH           800
# 1     2018-01-01         AS                 90    ANC  SEA          1405
# 2     2018-01-01         9E               3897    DTW  PHL          1230
# 3     2018-01-01         9E               4130    LGA  BUF          1124
# 4     2018-01-01         B6                167    JFK  OAK          2059
# ...          ...        ...                ...    ...  ...           ...
# 7256  2018-12-31         F9                423    ATL  DEN          2141
# 7257  2018-12-31         OO               5277    ORD  CHA          1440
# 7258  2018-12-31         OO               5427    OKC  SFO           745
# 7259  2018-12-31         OO               5731    SFO  RNO          1505
# 7260  2018-12-31         AA                460    PHX  ORD          1312
#
#       dep_time  dep_delay  taxi_out  wheels_off  wheels_on  taxi_in  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7261 entries, 0 to 7260
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fl_date              7261 non-null   object
#  1   op_carrier           7261 non-null   object
#  2   op_carrier_fl_num    7261 non-null   int64
#  3   origin               7261 non-null   object
#  4   dest                 7261 non-null   object
#  5   crs_dep_time         7261 non-null   int64
#  6   dep_time             7151 non-null   float64
#  7   dep_delay            7145 non-null   float64
#  8   taxi_out             7150 non-null   float64
#  9   wheels_off           7150 non-null   float64
#  10  wheels_on            7148 non-null   float64
#  11  taxi_in              7148 non-null   float64
#  12  crs_arr_time         7261 non-null   int64
#  13  arr_time             7148 non-null   float64
#  14  arr_delay            7123 non-null   float64
# ...

# %%
df.cancelled.value_counts()
# Out:
# 0.0    7150
# 1.0     111
# Name: cancelled, dtype: int64
